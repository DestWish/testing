# %%
import pytest

# %% [markdown]
# Метод принимающий строку и возвращающий ее длину. Тесты на пустую строку, многострочные, из пробелов.

# %%
# %%writefile strlen.py
def strlen(a: str) -> int:
    return len(a)
# Out:
# Writing strlen.py

# %%
# %%writefile test_strlen.py
import pytest
from strlen import strlen

@pytest.mark.parametrize("a, expected", [
    ("", 0),
    ("     ", 5),
    ("1234567890", 10),
    ("1234567890" 
     "1234567890", 20),
])

def test_strlen(a, expected):
    assert strlen(a) == expected
# Out:
# Overwriting test_strlen.py

# %%
# !pytest test_strlen.py -v
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.13.3, pytest-9.0.1, pluggy-1.6.0 -- C:\Users\DestWish\AppData\Local\Programs\Python\Python313\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\DestWish\Desktop\колледж\teating
# plugins: sugar-1.1.1
# collecting ... collected 8 items
#
# test_strToNewFile.py::test_strToNewFile[] PASSED                         [ 12%]
# test_strToNewFile.py::test_strToNewFile[     ] PASSED                    [ 25%]
# test_strToNewFile.py::test_strToNewFile[1234567890] PASSED               [ 37%]
# test_strToNewFile.py::test_strToNewFile[12345678901234567890] PASSED     [ 50%]
# test_strlen.py::test_strlen[-0] PASSED                                   [ 62%]
# test_strlen.py::test_strlen[     -5] PASSED                              [ 75%]
# test_strlen.py::test_strlen[1234567890-10] PASSED                        [ 87%]
# test_strlen.py::test_strlen[12345678901234567890-20] PASSED              [100%]
#
# ============================== 8 passed in 0.04s ==============================

# %% [markdown]
# Метод сохраняющий строку в файл.

# %%
# %%writefile strToNewFile.py
def strToNewFile(a: str, filename: str) -> None:
    with open(filename, 'w') as f:
        f.write(a)
# Out:
# Overwriting strToNewFile.py

# %%
# %%writefile test_strToNewFile.py
import pytest
from strToNewFile import strToNewFile




@pytest.mark.parametrize("a", [
    (""),
    ("     "),
    ("1234567890"),
    ("1234567890" 
     "1234567890"),
])
def test_strToNewFile(a):
    strToNewFile(a, "example.txt")
    with open("example.txt", "r", encoding="utf-8") as f:
        assert f.read() == a
# Out:
# Overwriting test_strToNewFile.py

# %%
# !pytest test_strToNewFile.py -v
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.13.3, pytest-9.0.1, pluggy-1.6.0 -- C:\Users\DestWish\AppData\Local\Programs\Python\Python313\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\DestWish\Desktop\колледж\teating
# plugins: sugar-1.1.1
# collecting ... collected 4 items
#
# test_strToNewFile.py::test_strToNewFile[] PASSED                         [ 25%]
# test_strToNewFile.py::test_strToNewFile[     ] PASSED                    [ 50%]
# test_strToNewFile.py::test_strToNewFile[1234567890] PASSED               [ 75%]
# test_strToNewFile.py::test_strToNewFile[12345678901234567890] PASSED     [100%]
#
# ============================== 4 passed in 0.03s ==============================
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
