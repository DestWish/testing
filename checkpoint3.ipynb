# %%
# %%writefile is_even.py
def is_even(number):
    return number % 2 == 0
# Out:
# Writing is_even.py

# %%
# %%writefile test_is_even.py
import pytest
from is_even import is_even

@pytest.mark.parametrize("number, expected", [
    (2, True),
    (3, False),
    (0, True),
    (-2, True),
    (-3, False)])
def test_is_even(number, expected):
    assert is_even(number) == expected
# Out:
# Writing test_is_even.py

# %%
# !pytest test_is_even.py -v
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.13.3, pytest-9.0.1, pluggy-1.6.0 -- C:\Users\DestWish\AppData\Local\Programs\Python\Python313\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\DestWish\Desktop\колледж\teating
# plugins: sugar-1.1.1
# collecting ... collected 5 items
#
# test_is_even.py::test_is_even[2-True] PASSED                             [ 20%]
# test_is_even.py::test_is_even[3-False] PASSED                            [ 40%]
# test_is_even.py::test_is_even[0-True] PASSED                             [ 60%]
# test_is_even.py::test_is_even[-2-True] PASSED                            [ 80%]
# test_is_even.py::test_is_even[-3-False] PASSED                           [100%]
#
# ============================== 5 passed in 0.02s ==============================

# %%
# %%writefile calculate_area.py
def calculate_area(length, width):
    return length * width
# Out:
# Writing calculate_area.py

# %%
# %%writefile test_calculate_area.py
import pytest
from calculate_area import calculate_area
@pytest.mark.parametrize("length, width, expected", [
    (2, 3, 6),
    (0, 5, 0),
    (4, 4, 16),
    (7, 2, 14),
    (5, 0, 0)])
def test_calculate_area(length, width, expected):
    assert calculate_area(length, width) == expected
# Out:
# Writing test_calculate_area.py

# %%
# !pytest test_calculate_area.py -v
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.13.3, pytest-9.0.1, pluggy-1.6.0 -- C:\Users\DestWish\AppData\Local\Programs\Python\Python313\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\DestWish\Desktop\колледж\teating
# plugins: sugar-1.1.1
# collecting ... collected 5 items
#
# test_calculate_area.py::test_calculate_area[2-3-6] PASSED                [ 20%]
# test_calculate_area.py::test_calculate_area[0-5-0] PASSED                [ 40%]
# test_calculate_area.py::test_calculate_area[4-4-16] PASSED               [ 60%]
# test_calculate_area.py::test_calculate_area[7-2-14] PASSED               [ 80%]
# test_calculate_area.py::test_calculate_area[5-0-0] PASSED                [100%]
#
# ============================== 5 passed in 0.02s ==============================

# %%
# %%writefile classify_triangle.py
def classify_triangle(a, b, c):
    if a == b == c:
        return "Равносторонний"
    elif a == b or b == c or a == c:
        return "Равнобедренный"
    else:
        return "Разносторонний"
# Out:
# Writing classify_triangle.py

# %%
# %%writefile test_classify_triangle.py
import pytest
from classify_triangle import classify_triangle

@pytest.mark.parametrize("a, b, c, expected", [
    (3, 3, 3, "Равносторонний"),
    (4, 4, 4, "Равносторонний"),
    (4, 3, 3, "Равнобедренный"),
    (3, 3, 4, "Равнобедренный"),
    (3, 4, 5, "Разносторонний")])
def test_classify_triangle(a, b, c, expected):
    assert classify_triangle(a, b, c) == expected
# Out:
# Writing test_classify_triangle.py

# %%
# !pytest test_classify_triangle.py -v
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.13.3, pytest-9.0.1, pluggy-1.6.0 -- C:\Users\DestWish\AppData\Local\Programs\Python\Python313\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Users\DestWish\Desktop\колледж\teating
# plugins: sugar-1.1.1
# collecting ... collected 5 items
#
# test_classify_triangle.py::test_classify_triangle[3-3-3-\u0420\u0430\u0432\u043d\u043e\u0441\u0442\u043e\u0440\u043e\u043d\u043d\u0438\u0439] PASSED [ 20%]
# test_classify_triangle.py::test_classify_triangle[4-4-4-\u0420\u0430\u0432\u043d\u043e\u0441\u0442\u043e\u0440\u043e\u043d\u043d\u0438\u0439] PASSED [ 40%]
# test_classify_triangle.py::test_classify_triangle[4-3-3-\u0420\u0430\u0432\u043d\u043e\u0431\u0435\u0434\u0440\u0435\u043d\u043d\u044b\u0439] PASSED [ 60%]
# test_classify_triangle.py::test_classify_triangle[3-3-4-\u0420\u0430\u0432\u043d\u043e\u0431\u0435\u0434\u0440\u0435\u043d\u043d\u044b\u0439] PASSED [ 80%]
# test_classify_triangle.py::test_classify_triangle[3-4-5-\u0420\u0430\u0437\u043d\u043e\u0441\u0442\u043e\u0440\u043e\u043d\u043d\u0438\u0439] PASSED [100%]
#
# ============================== 5 passed in 0.03s ==============================
